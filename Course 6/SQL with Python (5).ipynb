# %% [markdown]
# # Databases and SQL for Data Science with Python - Week 5 - Final Assignment

# %%
# !pip install sqlalchemy==1.3.9
# !pip install ibm_db_sa

# %%
# %load_ext sql

# %%
# Enter the connection string for your Db2 on Cloud database instance below
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name
# %sql ibm_db_sa://jns23982:m%2Bh763z5l9zbwrbd@dashdb-txn-sbox-yp-dal09-12.services.dal.bluemix.net:50000/BLUDB
# Out:
# 'Connected: jns23982@BLUDB'

# %%
# type in your query to retrieve list of all tables in the database for your db2 schema (username)
# %sql SELECT * FROM syscat.tables WHERE tabschema = 'JNS23982';
# Out:
#  * ibm_db_sa://jns23982:***@dashdb-txn-sbox-yp-dal09-12.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('JNS23982', 'PETRESCUE', 'JNS23982', 'U', 'T', 'N', None, None, None, None, datetime.datetime(2021, 5, 14, 8, 50, 39, 268186), datetime.datetime(2021, 5, 14, 8, 51, 17, 136161), datetime.datetime(2021, 5, 14, 8, 51, 17, 136190), datetime.datetime(2021, 5, 14, 8, 57, 50, 407094), 5, 4, 3342, 9, 1, 0, 1, -1, -1, -1, 0, 'jns23982space1', None, None, 0, 0, 0, 1, 1, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 1, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, 'N', 999, 0, 0.0, 38, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 5, 14, 8, 50, 39, 268186), 0, ' ', None, None, 'N', 'JNS23982', ' ', ' ', ' ', datetime.date(2021, 5, 20), ' ', 'N', 'R', 'N', -1.0, None),
# ...

# %%
# type in your query to retrieve the number of columns in the SCHOOLS table

# %sql SELECT count(*) FROM syscat.columns WHERE tabname = 'SCHOOLS';
# Out:
#  * ibm_db_sa://jns23982:***@dashdb-txn-sbox-yp-dal09-12.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('79'),)]

# %% [markdown]
# ## Problems
#
# ### Problem 1
#
# ##### Find the total number of crimes recorded in the CRIME table.

# %%
# %sql SELECT COUNT(*) FROM CHICAGO_CRIME_DATA;
# Out:
#  * ibm_db_sa://jns23982:***@dashdb-txn-sbox-yp-dal09-12.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('533'),)]

# %% [markdown]
# ### Problem 2
#
# ##### List community areas with per capita income less than 11000.

# %%
# %sql SELECT COMMUNITY_AREA_NAME, PER_CAPITA_INCOME FROM CENSUS_DATA WHERE PER_CAPITA_INCOME < 11000;
# Out:
#  * ibm_db_sa://jns23982:***@dashdb-txn-sbox-yp-dal09-12.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('West Garfield Park', 10934),
#  ('South Lawndale', 10402),
#  ('Fuller Park', 10432),
#  ('Riverdale', 8201)]

# %% [markdown]
# ### Problem 3
#
# ##### List all case numbers for crimes involving minors?

# %%
# %sql SELECT * FROM CHICAGO_CRIME_DATA WHERE DESCRIPTION LIKE '%MINOR%';
# Out:
#  * ibm_db_sa://jns23982:***@dashdb-txn-sbox-yp-dal09-12.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(514, 3987219, 'HL266884', datetime.date(2005, 3, 31), '024XX N CLARK ST', '2210', 'LIQUOR LAW VIOLATION', 'SELL/GIVE/DEL LIQUOR TO MINOR', 'CONVENIENCE STORE', 'True', 'False', 2333, 19, Decimal('43.0'), Decimal('7.0'), '22', Decimal('1172680.0'), Decimal('1916483.0'), 2005, '41.92626872', Decimal('-87.64089934000000'), '(41.926268719, -87.640899336)'),
#  (515, 3266814, 'HK238408', datetime.date(2004, 3, 13), '093XX S STONY ISLAND AVE', '2230', 'LIQUOR LAW VIOLATION', 'ILLEGAL CONSUMPTION BY MINOR', 'ALLEY', 'True', 'False', 413, 4, Decimal('8.0'), Decimal('48.0'), '22', Decimal('1188539.0'), Decimal('1843379.0'), 2004, '41.72530099', Decimal('-87.58496589000000'), '(41.72530099, -87.584965887)')]

# %% [markdown]
# ### Problem 4
#
# ##### List all kidnapping crimes involving a child?(children are not considered minors for the purposes of crime analysis)

# %%
# %%sql SELECT * FROM CHICAGO_CRIME_DATA WHERE PRIMARY_TYPE LIKE '%KIDNAPPING%'
# AND DESCRIPTION LIKE '%CHILD%';
# Out:
#  * ibm_db_sa://jns23982:***@dashdb-txn-sbox-yp-dal09-12.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(520, 5276766, 'HN144152', datetime.date(2007, 1, 26), '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 'False', 'False', 1533, 15, Decimal('29.0'), Decimal('25.0'), '20', Decimal('1143050.0'), Decimal('1897546.0'), 2007, '41.87490841', Decimal('-87.75024931000000'), '(41.874908413, -87.750249307)')]

# %% [markdown]
# ### Problem 5
#
# ##### What kind of crimes were recorded at schools?

# %%
# %%sql
# SELECT PRIMARY_TYPE
#    FROM CHICAGO_CRIME_DATA CCD, CHICAGO_PUBLIC_SCHOOLS CPS
#     WHERE CCD.LOCATION = CPS."Location";
# Out:
#  * ibm_db_sa://jns23982:***@dashdb-txn-sbox-yp-dal09-12.services.dal.bluemix.net:50000/BLUDB
# Done.
# []

# %% [markdown]
# ### Problem 6
#
# ##### List the average safety score for all types of schools.

# %%
# %%sql SELECT "Elementary, Middle, or High School", AVG(SAFETY_SCORE) AS AVG_SAFETY_SCORE FROM CHICAGO_PUBLIC_SCHOOLS
# GROUP BY "Elementary, Middle, or High School";
# Out:
#  * ibm_db_sa://jns23982:***@dashdb-txn-sbox-yp-dal09-12.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('ES', Decimal('49.5203836930455635491606714628')),
#  ('HS', Decimal('49.6235294117647058823529411764')),
#  ('MS', Decimal('48.0000000000000000000000000000'))]

# %% [markdown]
# ### Problem 7
#
# ##### List 5 community areas with highest % of households below poverty line.

# %%
# %%sql SELECT COMMUNITY_AREA_NAME, PERCENT_HOUSEHOLDS_BELOW_POVERTY FROM CENSUS_DATA
# ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY DESC LIMIT 5;
# Out:
#  * ibm_db_sa://jns23982:***@dashdb-txn-sbox-yp-dal09-12.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Riverdale', Decimal('56.5')),
#  ('Fuller Park', Decimal('51.2')),
#  ('Englewood', Decimal('46.6')),
#  ('North Lawndale', Decimal('43.1')),
#  ('East Garfield Park', Decimal('42.4'))]

# %% [markdown]
# ### Problem 8
#
# ##### Which community area(number) is most crime prone?

# %%
# %%sql SELECT COMMUNITY_AREA_NUMBER, COMMUNITY_AREA_NAME, HARDSHIP_INDEX FROM CENSUS_DATA
# ORDER BY HARDSHIP_INDEX DESC NULLS LAST LIMIT 5;
# Out:
#  * ibm_db_sa://jns23982:***@dashdb-txn-sbox-yp-dal09-12.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('54.0'), 'Riverdale', Decimal('98.0')),
#  (Decimal('37.0'), 'Fuller Park', Decimal('97.0')),
#  (Decimal('30.0'), 'South Lawndale', Decimal('96.0')),
#  (Decimal('68.0'), 'Englewood', Decimal('94.0')),
#  (Decimal('63.0'), 'Gage Park', Decimal('93.0'))]

# %% [markdown]
# ### Problem 9
#
# ##### Use a sub-query to find the name of the community area with highest hardship index.

# %%
# %%sql SELECT COMMUNITY_AREA_NUMBER, COMMUNITY_AREA_NAME, HARDSHIP_INDEX FROM CENSUS_DATA
# WHERE HARDSHIP_INDEX = (SELECT MAX(HARDSHIP_INDEX) FROM CENSUS_DATA);
# Out:
#  * ibm_db_sa://jns23982:***@dashdb-txn-sbox-yp-dal09-12.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('54.0'), 'Riverdale', Decimal('98.0'))]

# %% [markdown]
# ### Problem 10
#
# ##### Use a sub-query to determine the Community Area Name with most number of crimes?

# %%
# %%sql SELECT CD.COMMUNITY_AREA_NAME, COUNT(CCD.CASE_NUMBER) AS NUMBER_OF_CRIMES
# FROM CENSUS_DATA CD, CHICAGO_CRIME_DATA CCD
# WHERE CD.COMMUNITY_AREA_NUMBER = CCD.COMMUNITY_AREA_NUMBER
# GROUP BY CD.COMMUNITY_AREA_NAME
# ORDER BY NUMBER_OF_CRIMES DESC
# FETCH FIRST 5 ROWS ONLY;
# Out:
#  * ibm_db_sa://jns23982:***@dashdb-txn-sbox-yp-dal09-12.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Austin', Decimal('43')),
#  ('Humboldt park', Decimal('22')),
#  ('Englewood', Decimal('21')),
#  ('Near West Side', Decimal('16')),
#  ('North Lawndale', Decimal('16'))]
